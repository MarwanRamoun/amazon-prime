# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv("amazon_prime_titles.csv")

# %% [markdown]
# # task
# ### 1- Understanding what content is available in different countries
# ### 2- Network analysis of Actors / Directors and find interesting insights
# ### 3- Does Amazon Prime has more focus on TV Shows than movies in recent years.

# %%
df_copy=df
df_copy
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df=df.drop_duplicates()
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2082
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df=df.dropna(subset=['director'])

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast             634
# country         7017
# date_added      7570
# release_year       0
# rating           330
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df_country=df.dropna(subset=['country'])

# %%
df_country.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast             16
# country           0
# date_added      553
# release_year      0
# rating           15
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %% [markdown]
# ## Task 1 Understanding what content is available in different countries

# %%
df_country.country.value_counts()
# Out:
# India                                213
# United States                        194
# United Kingdom                        24
# Canada                                16
# United Kingdom, United States          9
#                                     ...
# Australia, United States, Germany      1
# Germany, Austria, United States        1
# France, China, Belgium, Monaco         1
# Egypt                                  1
# Italy, Spain                           1
# Name: country, Length: 79, dtype: int64

# %% [markdown]
# # United States

# %%
df_country_drama=df_country[df_country["country"]=="United States"]
df_country_drama.listed_in.value_counts()
# Out:
# Drama                                                 29
# Comedy                                                17
# Comedy, Drama                                         10
# Documentary                                           10
# Drama, Suspense                                        8
#                                                       ..
# Documentary, Science Fiction, Special Interest         1
# Animation, Kids                                        1
# Animation, Suspense                                    1
# Arthouse, Arts, Entertainment, and Culture, Comedy     1
# Comedy, Drama, Kids                                    1
# Name: listed_in, Length: 75, dtype: int64

# %% [markdown]
# ## United States  interested in
# ### Drama,Documentary and  Comedy

# %% [markdown]
# # India

# %%
df_country_drama=df_country[df_country["country"]=="India"]
df_country_drama.listed_in.value_counts()
# Out:
# Drama, International                                      23
# Drama, International, Romance                             16
# Comedy, Drama, International                              16
# Comedy, Drama                                             13
# Action, Drama, International                              12
# Comedy                                                    10
# Suspense                                                  10
# Drama                                                      9
# Comedy, International                                      8
# Romance                                                    7
# Drama, Suspense                                            6
# International, Suspense                                    6
# International, Romance                                     6
# Drama, International, Suspense                             6
# Action, International                                      6
# ...

# %% [markdown]
# # India intersetd in
# ### Drama,Romance,Comedy and Action

# %% [markdown]
# # United Kingdom

# %%
df_country_drama=df_country[df_country["country"]=="United Kingdom"]
df_country_drama.listed_in.value_counts()
# Out:
# Documentary                               6
# Documentary, Music Videos and Concerts    2
# Drama, Fantasy                            1
# Drama                                     1
# Comedy, Drama, Romance                    1
# Horror, Suspense                          1
# Horror, Science Fiction                   1
# Action, Drama, Suspense                   1
# Action, Adventure, Drama                  1
# Comedy                                    1
# Documentary, Special Interest             1
# Fantasy, Kids                             1
# Adventure, Comedy                         1
# Action                                    1
# Adventure, Animation, Kids                1
# Special Interest                          1
# Comedy, Horror                            1
# Action, Adventure, Science Fiction        1
# Name: listed_in, dtype: int64

# %% [markdown]
# ## United Kingdom
# ### Documentary,Fantasy and Drama

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast             634
# country         7017
# date_added      7570
# release_year       0
# rating           330
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df_cast= df_country=df.dropna(subset=['cast'])
df_cast
# Out:
#      show_id   type                 title  \
# 0         s1  Movie   The Grand Seduction
# 1         s2  Movie  Take Care Good Night
# 2         s3  Movie  Secrets of Deception
# 3         s4  Movie    Pink: Staying True
# 4         s5  Movie         Monster Maker
# ...      ...    ...                   ...
# 9660   s9661  Movie    The Man in the Hat
# 9662   s9663  Movie                 River
# 9663   s9664  Movie   Pride Of The Bowery
# 9665   s9666  Movie               Outpost
# 9667   s9668  Movie           Harry Brown
#
#                                  director  \
# 0                            Don McKellar
# 1                            Girish Joshi
# 2                             Josh Webber
# 3                          Sonia Anderson
# 4                            Giles Foster
# ...                                   ...
# 9660  John-Paul Davidson, Stephen Warbeck
# 9662                           Emily Skye
# 9663                      Joseph H. Lewis
# ...

# %% [markdown]
# ### Task 2 Network analysis of Actors / Directors and find interesting insights

# %%
df0= df_cast.director.value_counts(ascending=False).to_frame()
df0.head(10)
# Out:
#                     director
# Mark Knight               43
# Jay Chapman               34
# Manny Rodriguez           22
# John English              20
# Cannis Holder             19
# 1                         16
# Brian Volk-Weiss          15
# Joseph Kane               13
# Michael J. Nelson         12
# George Archainbaud        12

# %% [markdown]
# # director Mark Knight

# %%
df_cast_mark=df_cast[df_cast["director"]=="Mark Knight"]
df_cast_mark
# Out:
#      show_id   type                                              title  \
# 38       s39  Movie                        Yoga with Sound Meditations
# 39       s40  Movie                 Yoga to Harness Your Chakra Energy
# 40       s41  Movie                        Yoga to Ease Flight Anxiety
# 41       s42  Movie                            Yoga to Break Any Habit
# 43       s44  Movie                           Yoga Savasana Relaxation
# 44       s45  Movie                       Yoga for Relaxation Anywhere
# 45       s46  Movie     Yoga for Relaxation and Stress Relief Anywhere
# 46       s47  Movie              Yoga for Relaxation and Stress Relief
# 47       s48  Movie                Yoga for Mindfulness and Meditation
# 48       s49  Movie                              Yoga for Men's Health
# 49       s50  Movie                          Yoga for Breath Awareness
# 50       s51  Movie                                 Yoga For Beginners
# ...

# %%
df_cast_mark.cast.value_counts()
# Out:
# Anne-Marie Newland                   23
# Mary Kay Kayaltizer                   6
# Dr Daniel J Nightingale               3
# Kimiko Ishizaka                       2
# Ann-Marie Newland                     1
# Caroline Shola Arewa                  1
# Steves Bedroom Band                   1
# Anne-Marie Newland, Jamie Newland     1
# Ben Leinbach                          1
# Nick Mortorano,  Phd                  1
# Niv Dayan, Sarah Lærke                1
# Ken Elkinson                          1
# Marie-Anne Newland                    1
# Name: cast, dtype: int64

# %% [markdown]
# ## mark knight like to work with Anne-Marie Newland and Mary Kay Kayaltizer
# ## most of his work listed in fitness, yoga and Music Videos

# %% [markdown]
# # -------------------------------------------------------------------------
# # Jay Chapman

# %%
df_cast_jay=df_cast[df_cast["director"]=="Jay Chapman"]
df_cast_jay
# Out:
#      show_id   type                                           title  \
# 303     s304  Movie                 Tom Rhodes: Light, Sweet, Crude
# 305     s306  Movie                           Tom Papa: Freaked Out
# 316     s317  Movie                   Todd Glass: Talks About Stuff
# 448     s449  Movie  The Sklar Brothers: What Are We Talking About?
# 999    s1000  Movie                     Sinbad: Make Me Wanna Holla
# 1038   s1039  Movie                      Shane Mauss: Mating Season
# 1493   s1494  Movie                        Nick Di Paolo: Raw Nerve
# 1495   s1496  Movie                   Nick Cannon: F--k Nick Cannon
# 1537   s1538  Movie            Myq Kaplan: Small, Dork and Handsome
# 1951   s1952  Movie           Kevin Nealon: Whelmed, But Not Overly
# 1953   s1954  Movie           Kevin Hart Presents: Plastic Cup Boyz
# 1959   s1960  Movie                 Kathleen Madigan: Madigan Again
# 2054   s2055  Movie                          Jasper Redd: Jazz Talk
# ...

# %%
df_cast_jay.cast.value_counts()
# Out:
# Tom Papa                                                    2
# Lisa Lampanelli                                             1
# Colin Quinn                                                 1
# Christian Finnegan                                          1
# Chris Porter                                                1
# Brian Posehn                                                1
# Brent Weinbach                                              1
# Bob Saget                                                   1
# Tom Rhodes                                                  1
# Dana Gould                                                  1
# D.L. Hughley                                                1
# Tammy Pescatelli                                            1
# Arnez J                                                     1
# Adam Newman                                                 1
# Tom Segura                                                  1
# ...

# %% [markdown]
# # Manny Rodriguez

# %%
df_cast_manny=df_cast[df_cast["director"]=="Manny Rodriguez"]
df_cast_manny
# Out:
#      show_id   type                                       title  \
# 299     s300  Movie                 Tom Wilson: Bigger Than You
# 896     s897  Movie             Steve Byrne: The Byrne Identity
# 1679   s1680  Movie            Michael McDonald: Model. Citizen
# 1680   s1681  Movie              Michael Loftus: You've Changed
# 1819   s1820  Movie                 Loni Love: America's Sister
# 2012   s2013  Movie            John Heffron: Middle Class Funny
# 2687   s2688  Movie   Debra DiGiovanni: Single, Awkward, Female
# 2768   s2769  Movie                   Craig Shoemaker: Daditude
# 2951   s2952  Movie                     Bryan Callen: Man Class
# 3010   s3011  Movie             Bobby Slayton: Born To Be Bobby
# 3064   s3065  Movie                     Billy Gardell: Halftime
# 3309   s3310  Movie      Alonzo Bodden: Who's Paying Attention?
# 3686   s3687  Movie               Danny Bhoy: Subject to Change
# 3840   s3841  Movie            Jeff Dunham: Arguing with Myself
# ...

# %%
df_cast_manny.cast.value_counts()
# Out:
# Tom Wilson                        1
# Steve Byrne                       1
# Steve Brown                       1
# Sebastian Maniscalco              1
# Jamie Kennedy                     1
# Pablo Francisco                   1
# Anjelah Johnson                   1
# Gina Brillon, Gabriel Iglesias    1
# Hal Sparks                        1
# Jeff Dunham                       1
# Danny Bhoy                        1
# Alonzo Bodden                     1
# Billy Gardell                     1
# Bobby Slayton                     1
# Bryan Callen                      1
# Craig Shoemaker                   1
# Debra DiGiovanni                  1
# John Heffron                      1
# Loni Love                         1
# Michael Loftus                    1
# Michael McDonald                  1
# Erik Rivera                       1
# Name: cast, dtype: int64

# %% [markdown]
# # Manny Rodriguez and Jay Chapman specialist in directing  stand-up comedian

# %% [markdown]
# # -------------------------------------------------------------------------

# %%
df_cast_john=df_cast[df_cast["director"]=="John English"]
df_cast_john
# Out:
#      show_id   type                          title      director  \
# 1101   s1102  Movie            San Fernando Valley  John English
# 1152   s1153  Movie  Riders of the Whistling Pines  John English
# 3581   s3582  Movie            Trail To San Antone  John English
# 4751   s4752  Movie              The Last Round-Up  John English
# 4767   s4768  Movie              Rim Of The Canyon  John English
# 4768   s4769  Movie  Riders Of The Whistling Pines  John English
# 4776   s4777  Movie                 Loaded Pistols  John English
# 5488   s5489  Movie     The Cowboy And The Indians  John English
# 5491   s5492  Movie             Sons Of New Mexico  John English
# 5496   s5497  Movie              Riders In The Sky  John English
# 5499   s5500  Movie                     Mule Train  John English
# 5514   s5515  Movie                       Cow Town  John English
# 6207   s6208  Movie                The Blazing Sun  John English
# ...

# %%
df_cast_john.cast.value_counts()
# Out:
# Gene Autry, Champion, Gail Davis                                                                         6
# Gene Autry, Champion, Sheila Ryan                                                                        2
# Roy Rogers, Dale Evans, Jean Porter, Andrew Tombes, Bob Nolan & The Sons of the Pioneers, LeRoy Mason    1
# Gene Autry, Patricia Barry                                                                               1
# Gene Autry, Champion Jr., Peggy Stewart                                                                  1
# Gene Autry, Champion, Jean Heather                                                                       1
# Gene Autry, Champion, Nan Leslie                                                                         1
# Gene Autry, Champion, Patricia Barry                                                                     1
# Gene Autry, Barbara Britton, Chill Wills                                                                 1
# ...

# %% [markdown]
# # John English is from classic genration he likes actors Gene Autry,Champion and Gail Davis

# %% [markdown]
# ### Task 3 Does Amazon Prime has more focus on TV Shows than movies in recent years.

# %%
df_copy.describe()
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
ax = sns.countplot(x= "release_year",hue="type", data=df_copy, palette="Pastel2")

# %%
df_copy.release_year.value_counts()
df_copy1=df_copy[df_copy.release_year>=2016]

# %%
df_copy1.release_year.value_counts()
# Out:
# 2021    1442
# 2020     962
# 2019     929
# 2018     623
# 2017     562
# 2016     521
# Name: release_year, dtype: int64

# %%
ax = sns.countplot(x= "release_year",hue="type", data=df_copy1, palette="Pastel2")

# %%
df_copy1
# Out:
#      show_id     type                    title  \
# 1         s2    Movie     Take Care Good Night
# 2         s3    Movie     Secrets of Deception
# 6         s7    Movie                Hired Gun
# 7         s8    Movie             Grease Live!
# 8         s9    Movie          Global Meltdown
# ...      ...      ...                      ...
# 9656   s9657    Movie       Anaganaga Oka Nenu
# 9660   s9661    Movie       The Man in the Hat
# 9662   s9663    Movie                    River
# 9664   s9665  TV Show            Planet Patrol
# 9666   s9667  TV Show  Maradona: Blessed Dream
#
#                                  director  \
# 1                            Girish Joshi
# 2                             Josh Webber
# 6                             Fran Strine
# 7             Thomas Kail, Alex Rudzinski
# 8                           Daniel Gilboy
# ...                                   ...
# 9656                             Vamshi P
# 9660  John-Paul Davidson, Stephen Warbeck
# ...
